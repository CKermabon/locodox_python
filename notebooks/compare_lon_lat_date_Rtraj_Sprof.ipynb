# %%
import matplotlib.pyplot as plt
import sys
sys.path.insert(0,'../')
from m_argo_data import read_argo_data
from m_NCEP_read import read_NCEP
from m_WOA_data import read_WOA
from m_fonctions import watervapor
import numpy as np
import xarray as xr
import warnings
warnings.filterwarnings("ignore",category=RuntimeWarning)

# %%
ds_Rtraj = xr.open_dataset('/Users/chemon/ARGO_NEW/NEW_LOCODOX/data_test/6902802/6902802_Rtraj.nc')
ds_Sprof = xr.open_dataset('/Users/chemon/ARGO_NEW/NEW_LOCODOX/data_test/6902802/6902802_Sprof.nc')

# %%
plt.figure()
plt.plot(ds_Sprof['LONGITUDE'],ds_Sprof['LATITUDE'],'xb')
plt.plot(ds_Rtraj['LONGITUDE'],ds_Rtraj['LATITUDE'],'+r')
